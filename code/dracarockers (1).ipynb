# %%
import time

# %% [markdown]
# # For In

# %%
listaDeMusicas = ["Back in Black", "Paranoid", "Everlong"]
for musica in listaDeMusicas:
  print("Próxima Música: ", musica)
print("Fim dos fados!")
# Out:
# Próxima Música:  Back in Black
# Próxima Música:  Paranoid
# Próxima Música:  Everlong
# Fim dos fados!

# %% [markdown]
# # For In com Range

# %%
for repeticao in range(1,5):
  print("Repetição do riff:", repeticao)
print("Cabo o ensaio!")

# %% [markdown]
# # While

# %%
ensaios_Drakarockers = 0
meta_ensaios = 3
while ensaios_Drakarockers < meta:
  ensaios_Drakarockers += 1
  print("Quantidade atual: ", ensaios_Drakarockers)
  time.sleep(0.9)
# Out:
# Quantidade atual:  1
# Quantidade atual:  2
# Quantidade atual:  3

# %% [markdown]
# # While com break

# %%
numero_da_musica = 0
total_de_musicas = 10

while numero_da_musica < total_de_musicas:
    numero_da_musica += 1
    print("Tocando a música número:", numero_da_musica)
    time.sleep(0.9)

    if numero_da_musica == 4:
        print("Arrebentou uma corda da guitarra da Tainá no meio do solo!")
        time.sleep(0.9)
        break

print("Fim do show da banda Drakarockers!")
# Out:
# Tocando a música número: 1
# Tocando a música número: 2
# Tocando a música número: 3
# Tocando a música número: 4
# Arrebentou uma corda da guitarra da Tainá no meio do solo!
# Fim do show da banda Drakarockers!

# %% [markdown]
# # Erros Comuns

# %%
verso_kurt = ["as you are", "as you were"]
while True:     # O contador não é incrementado, resultando em um loop infinito.
  for item_do_verso in verso_kurt: # Renomeei a variável para evitar confusão com o contador do while anterior
    print("Come", item_do_verso)
    time.sleep(1.0)
# Out:
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# Come as you are
# Come as you were
# ...

# %% [markdown]
# Esquecer o contador

# %%
repeticao = 0
acordes_baixo = 5
while repeticao < acordes_baixo:
  print(" * som de baixo tocando * ")
  time.sleep(4.0)
# Out:
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *
#  * som de baixo tocando *

# %% [markdown]
# Confundir o limite final de range()

# %%
for repeticao in range(1, 4):
	print("Repetição riff:", repeticao)
# Out:
# Repetição riff: 1
# Repetição riff: 2
# Repetição riff: 3

# %% [markdown]
# Utilizar o break em uma condição errada

# %%
numero_da_musica = 0
total_de_musicas = 10

while numero_da_musica < total_de_musicas:
    numero_da_musica += 1
    print("Tocando a música número:", numero_da_musica)

    if numero_da_musica == 1:
        print("Arrebentou uma corda da guitarra da Tainá no meio do solo!")
        break

print("Fim do show da banda Drakarockers!")
# Out:
# Tocando a música número: 1
# Arrebentou uma corda da guitarra da Tainá no meio do solo!
# Fim do show da banda Drakarockers!
